# %%
import numpy as np
import pandas as pd

# %%
#combination of series is known as data frame.
data = {
    'Name' : ['John', 'Piyush', 'Shyam', 'Ram', 'Krishna'],
    'Age' : [23,43,22,34,64],
    'City' : ['New york', 'paris','jaipur','kashmir','udaipur'],
    'salary' : [60000,70000,15000,120000,78000]
}
pd.DataFrame(data)
# Out:
#       Name  Age      City  salary
# 0     John   23  New york   60000
# 1   Piyush   43     paris   70000
# 2    Shyam   22    jaipur   15000
# 3      Ram   34   kashmir  120000
# 4  Krishna   64   udaipur   78000

# %%
data_list = [
    [ 'John', 28, 'New York', 65000], 
    [ 'Anna', 34, 'Paris', 70000], 
    ['Peter', 29, 'Berlin', 62000], 
    [ 'Linda', 42, 'London', 85000]
]

columns = ['Name','Age','City','salary']
df = pd.DataFrame(data_list,columns=columns)
df
# Out:
#     Name  Age      City  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df['Name']
df[['Name',
   'Age']]
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %%
df['Designitation']=['Employee','HR',"manager",'PA']

# %%
df
# Out:
#     Name  Age      City  salary Designitation
# 0   John   28  New York   65000      Employee
# 1   Anna   34     Paris   70000            HR
# 2  Peter   29    Berlin   62000       manager
# 3  Linda   42    London   85000            PA

# %%
## Remove columns
df.drop('Name',axis = 1, inplace=True)

# %%
df
# Out:
#    Age      City  salary
# 0   28  New York   65000
# 1   34     Paris   70000
# 2   29    Berlin   62000
# 3   42    London   85000

# %%
df.loc[[0,1]]
df.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# salary     85000
# Name: 3, dtype: object

# %% [markdown]
# ## subset of rows and columns

# %%
df.loc[[0,1]][['City','salary']]
# Out:
#        City  salary
# 0  New York   65000
# 1     Paris   70000

# %%
df.loc[[0,1]][['Name','Age']]
# Out:
#    Name  Age
# 0  John   28
# 1  Anna   34

# %% [markdown]
# ## Conditional selection

# %%
df[df['Age']>30]
# Out:
#     Name  Age    City  salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
df[(df['Age']>30)& (df['City']=='Paris')]
# Out:
#    Name  Age   City  salary
# 1  Anna   34  Paris   70000
